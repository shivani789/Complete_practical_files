# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani789/Complete_practical_files/blob/main/edge_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread('/content/drive/MyDrive/Tufnell Photography/Start upload/THB20 Olive Green/DSC_5021.jpg')
cv2_imshow(img)
edge_img = cv2.Canny(img,100,200)

cv2_imshow(edge_img)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x2000 at 0x7FF95016D710>
# <PIL.Image.Image image mode=L size=2000x2000 at 0x7FF95016D910>
# -1
