# %% [markdown]
# <a href="https://colab.research.google.com/github/shivani789/Complete_practical_files/blob/main/negative_of_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt 
import random as rn
from google.colab.patches import cv2_imshow

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

#img = cv2.imread('/content/drive/MyDrive/Goa/Final Output/20180102_012234A.jpg')
img = cv2.imread('/bat_cover.jpg')
length , breadth , channels=img.shape
inv_mask = np.full(img.shape, 255)
inv_img = inv_mask - img

plt.figure(figsize = (10, 10))
plt.imshow(img)
plt.figure(figsize = (10, 10))
plt.imshow(inv_img)
# Out:
# Mounted at /content/drive
